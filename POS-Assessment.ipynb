# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Parts of Speech Assessment

# %% [markdown]
# For this assessment we'll be using the short story [The Tale of Peter Rabbit](https://en.wikipedia.org/wiki/The_Tale_of_Peter_Rabbit) by Beatrix Potter (1902). <br>The story is in the public domain; the text file was obtained from [Project Gutenberg](https://www.gutenberg.org/ebooks/14838.txt.utf-8).

# %%
# RUN THIS CELL to perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy import displacy

# %%
import requests

# %%
url='https://www.gutenberg.org/cache/epub/14838/pg14838.txt'
response = requests.get(url)
text = response.text

# %% [markdown]
# **1. Create a Doc object from the file `peterrabbit.txt`**<br>
# > HINT: Use `with open('../TextFiles/peterrabbit.txt') as f:`

# %%
with open('C:\Users\classic pc\Documents\Pyth - HISB - Repo\day3-18.POS.txt', 'w+',encoding='utf8') as f:
    f.write(text)

# %%
# Enter your code here:
with open('C:\Users\classic pc\Documents\Pyth - HISB - Repo\day3-18.POS.txt', 'r+',  encoding='utf8') as f:
    print(f.read())
    print("File created")
f.close()
# Out:
# ï»¿The Project Gutenberg eBook of The Tale of Peter Rabbit
#
#
#
# This ebook is for the use of anyone anywhere in the United States and
#
# most other parts of the world at no cost and with almost no restrictions
#
# whatsoever. You may copy it, give it away or re-use it under the terms
#
# of the Project Gutenberg License included with this ebook or online
#
# at www.gutenberg.org. If you are not located in the United States,
#
# you will have to check the laws of the country where you are located
#
# before using this eBook.
#
#
#
# Title: The Tale of Peter Rabbit
#
#
#
#
#
# Author: Beatrix Potter
#
#
#
# Release date: January 30, 2005 [eBook #14838]
#
#                 Most recently updated: September 8, 2021
#
#
#
# Language: English
#
#
#
#
#
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK THE TALE OF PETER RABBIT ***
#
#
#
#
#
#
#
# [Illustration]
#
#
#
# THE TALE OF
#
#
#
# PETER RABBIT
#
#
#
# BY
#
#
#
# BEATRIX POTTER
#
#
#
# [Illustration]
#
#
#
# FREDERICK WARNE
#
#
#
#
# ...

# %%
with open('C:\Users\classic pc\Documents\Pyth - HISB - Repo\day3-18.POS.txt', 'r+', encoding='utf8') as f:
    print("Opened file")
    file_read = f.read()
doc = nlp(file_read)
# Out:
# Opened file

# %% [markdown]
# **2. For every token in the third sentence, print the token text, the POS tag, the fine-grained TAG tag, and the description of the fine-grained tag.**

# %%
# Enter your code here:
# Enter your code here:
for token in list(doc.sents)[2]:
    print(f"{token.text:{12}} {token.pos_:{8}} {token.tag_:{8}} {spacy.explain(token.tag_)} ")
# Out:
# You          PRON     PRP      pronoun, personal
# may          AUX      MD       verb, modal auxiliary
# copy         VERB     VB       verb, base form
# it           PRON     PRP      pronoun, personal
# ,            PUNCT    ,        punctuation mark, comma
# give         VERB     VB       verb, base form
# it           PRON     PRP      pronoun, personal
# away         ADV      RB       adverb
# or           CCONJ    CC       conjunction, coordinating
# re           VERB     VB       verb, base form
# -            VERB     VB       verb, base form
# use          VERB     VB       verb, base form
# it           PRON     PRP      pronoun, personal
# under        ADP      IN       conjunction, subordinating or preposition
# the          DET      DT       determiner
# terms        NOUN     NNS      noun, plural
#
#
#            SPACE    _SP      whitespace
# of           ADP      IN       conjunction, subordinating or preposition
# the          DET      DT       determiner
# ...

# %% [markdown]
# **3. Provide a frequency list of POS tags from the entire document**

# %%
pos_counts = doc.count_by(spacy.attrs.POS)
for k,v in sorted(pos_counts.items()):
    print(f"{k}. {doc.vocab[k].text:{5}} {v}")
# Out:
# 84. ADJ   246
# 85. ADP   542
# 86. ADV   118
# 87. AUX   182
# 89. CCONJ 212
# 90. DET   448
# 91. INTJ  3
# 92. NOUN  846
# 93. NUM   51
# 94. PART  97
# 95. PRON  267
# 96. PROPN 479
# 97. PUNCT 495
# 98. SCONJ 84
# 99. SYM   7
# 100. VERB  514
# 101. X     55
# 103. SPACE 445

# %% [markdown]
# **4. CHALLENGE: What percentage of tokens are nouns?**<br>
# HINT: the attribute ID for 'NOUN' is 91

# %%
sum_nouns = 0
sum_total = 0
for k,v in sorted(pos_counts.items()):
    sum_total += v
    if doc.vocab[k].text == 'NOUN':
        sum_nouns += v
print("%.2f" % ((sum_nouns/sum_total)*100)+'%')
# Out:
# 16.62%

# %%
# alternative solution
percent = 100*pos_counts[92]/len(doc)
print(f'{pos_counts[92]}/{len(doc)} = {percent:{.4}}%')
# Out:
# 846/5091 = 16.62%

# %% [markdown]
# **5. Display the Dependency Parse for the third sentence**

# %%
displacy.render(list(doc.sents)[2], style='dep', jupyter=True, options={'distance': 50})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="03b5fd77964144aca7814d7ea73afe95-0" class="displacy" width="1500" height="262.0" direction="ltr" style="max-width: none; height: 262.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="172.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">You</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="172.0">
#     <tspan class="displacy-word" fill="currentColor" x="100">may</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="172.0">
# ...

# %% [markdown]
# **6. Show the first two named entities from Beatrix Potter's *The Tale of Peter Rabbit* **

# %%
for ent in doc.ents[2:3]:
    print(ent.text + " - " + ent.label_ + " - " + spacy.explain(ent.label_)  )
# Out:
# The Tale of Peter Rabbit
#
#
#
#  - WORK_OF_ART - Titles of books, songs, etc.

# %% [markdown]
# **7. How many sentences are contained in *The Tale of Peter Rabbit*?**

# %%
len(list(doc.sents))
# Out:
# 185

# %% [markdown]
# **8. CHALLENGE: How many sentences contain named entities?**

# %%
num_sent_contains_ent = 0
for sent in doc.sents:
    if sent.ents:
        num_sent_contains_ent +=1
num_sent_contains_ent
# Out:
# 122

# %% [markdown]
# **9. CHALLENGE: Display the named entity visualization for `list_of_sents[0]` from the previous problem**

# %%
list_of_sents = list(doc.sents)
displacy.render(list_of_sents[4], style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Title:
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Tale of Peter Rabbit
#
#
#
#
#
# Author
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# : Beatrix Potter</br></br></br></br>Release date:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 30, 2005
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  </div></span>

# %% [markdown]
# ### Great Job!
